# %%
class Playlist:
  def __init__(self,nombre):
    self.nombre = nombre
    self.canciones=[]

  def añadir_cancion(self,titulo):
    if len(self.canciones) >= 5:
      print("Alcanzante el limite maximo de canciones por playlist")
    else:
      if titulo in self.canciones:
        print("La canción ya se encuentra en la playlist")
      else:
        self.canciones.append(titulo)
        print(f"{titulo} añadida a {self.nombre}.")

  def eliminar_cancion(self,titulo):
    if titulo in self.canciones:
      self.canciones.remove(titulo)
      print(f"{titulo} ha sido eliminado de {self.nombre}")
    else:
      print(f"{titulo} no esta en {self.nombre}")

  def total_canciones(self):
    return len(self.canciones)

  def mostrar_playlist(self):
    print(f"========== Playlist: {self.nombre} ==========")
    if len(self.canciones) == 0:
      print("La Playlist esta vacia actualmente")
    else:
      i = 1
      for titulo in self.canciones:
        print(i,titulo)
        i += 1

  def limpiar_playlist(self):
    self.canciones.clear()
    print("La playlist esta vacia")

  def buscador(self,texto):
    if texto in self.canciones:
      print(f"La cancion {texto} forma parte de la playlist {self.nombre}")
    else:
      print(f"La cancion {texto} no existe en la playlist {self.nombre}")

# %%
mix_pop = Playlist("Mi musica de Pop")

# %%
mix_pop.añadir_cancion("Beat")
# Out:
# Beat añadida a Mi musica de Pop.

# %%
mix_pop.añadir_cancion("Thiller")
# Out:
# Thiller añadida a Mi musica de Pop.

# %%
mix_pop.añadir_cancion("Smoth Criminal")
# Out:
# Smoth Criminal añadida a Mi musica de Pop.

# %%
mix_pop.buscador("Smoth")
# Out:
# La cancion Smoth no existe en la playlist Mi musica de Pop

# %%
mix_pop.añadir_cancion("Smoth Criminal")
# Out:
# La canción ya se encuentra en la playlist

# %%
mix_pop.mostrar_playlist()
# Out:
# ========== Playlist: Mi musica de Pop ==========
# 1 Beat
# 2 Thiller
# 3 Smoth Criminal

# %%
mix_pop.limpiar_playlist()
# Out:
# La playlist esta vacia

# %%
mix_pop.mostrar_playlist()
# Out:
# ========== Playlist: Mi musica de Pop ==========
# La Playlist esta vacia actualmente

# %%
mix_pop.añadir_cancion("Beat1")
# Out:
# Beat1 añadida a Mi musica de Pop.

# %%
mix_pop.añadir_cancion("Beat2")
# Out:
# Beat2 añadida a Mi musica de Pop.

# %%
mix_pop.añadir_cancion("Beat3")
# Out:
# Beat3 añadida a Mi musica de Pop.

# %%
mix_pop.añadir_cancion("Beat4")
# Out:
# Beat4 añadida a Mi musica de Pop.

# %%
mix_pop.añadir_cancion("Beat5")
# Out:
# Beat5 añadida a Mi musica de Pop.

# %%
mix_pop.añadir_cancion("Beat6")
# Out:
# Alcanzante el limite maximo de canciones por playlist

# %%
mix_pop.mostrar_playlist()
# Out:
# ========== Playlist: Mi musica de Pop ==========
# 1 Beat2
# 2 Beat3
# 3 Beat4
# 4 Beat1
# 5 Beat5
